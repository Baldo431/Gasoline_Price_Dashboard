# %%
import os

import pandas as pd

import numpy as np 
from pathlib import Path
from collections import Counter

from tqdm import tqdm
import json
import pandas as pd

import re

import matplotlib.pyplot as plt
import seaborn as sns

import spacy
nlp = spacy.load('en_core_web_sm')

from spacytextblob.spacytextblob import SpacyTextBlob
nlp.add_pipe('spacytextblob')

from string import punctuation as PUNCTUATION
from spacy.lang.en.stop_words import STOP_WORDS

from sklearn.model_selection import train_test_split
from sklearn.metrics import balanced_accuracy_score
from sklearn.metrics import confusion_matrix

# %%
# Changing Directory
os.chdir('/Users/annettedblackburn/Desktop/Data_Analytics_Bootcamp/Module 20 - Final (Group) Project')

# %%
os.listdir(os.curdir)
# Out:
# ['.DS_Store',
#  'crude-oil-price.csv',
#  'PET_PRI_GND_DCUS_NUS_W.csv',
#  'archive(2).zip',
#  'archive(1).zip',
#  'twitter_NLP.ipynb',
#  'gas_oil_ML.ipynb',
#  'tweets_clean.csv',
#  '.ipynb_checkpoints']

# %%
twitter_df = pd.read_csv("tweets_clean.csv")
twitter_df.head()
# Out:
#    Unnamed: 0                                         2022-11-24  \
# 0           0  @BellaWallerstei They have been paying oil and...
# 1           1  @BladeoftheS 3 The major difference between UK...
# 2           2  ¡Oil &amp; Gas Reporter está disponible! https...
# 3           3  @binnahar85 Europe wants to boycott Qatar? Are...
# 4           4  @TheoFleury14 This was always about $$ and the...
#
#                                           2022-11-25  \
# 0  @TrainerGonzo @Belinda71555585 It's that easy ...
# 1  @davidmweissman Clueless! Right he inherited e...
# 2  @laurenboebert Magic money? You mean from the ...
# 3  @thetruthsucks12 @haliwell51 @gmbutts No maybe...
# 4  You are full of it. You shut down our clean cr...
#
#                                           2022-11-26  \
# 0  @HouseGOP They tried to stick the gas price hi...
# 1  @AnnieForTruth Yep. I remember when an attenda...
# 2  @RBReich -\n...and the NATO Supremacists said,...
# 3  @Princemoye1 I thought its about those that ki...
# 4  The big story. Proof that Westminster has been...
#
#                                           2022-11-27  \
# 0    @GilHough @KamalaHarris https://t.co/LBgWDBW9xs
# 1  @NikkiHaley I agree use our own oil and coal a...
# 2  Nothing is being offered near Utah’s oil and g...
# 3  @Scott19490 @isaiahrmartin Yeah because relian...
# 4  @RepBoebert Lauren Boebert’s income is almost ...
#
#                                           2022-11-28  \
# 0  @ChrisMartzWX For well over 40 years, I have p...
# 1  @WhiteHouse His executive orders on the energy...
# 2  @manuel_rdgn @SEGOB_mx @adan_augusto @calderon...
# 3  rtr: U.S. seeks to limit flaring and methane l...
# 4  ¡Oil &amp; Gas Reporter está disponible! https...
#
#                                           2022-11-29  \
# 0  @POTUS Except that gas prices were on the rise...
# 1  @robreiner You really need help. Why are you s...
# 2  TCS is a proud sponsor of the Oil &amp; Gatsby...
# 3  Should California tax oil profits? Gas spike h...
# 4  This is a classic example of Washington corrup...
#
#                                           2022-11-30  \
# 0  @FinancialReview simply nonsense. Don't let th...
# 1  @GavinNewsom You could end the gas tax, but yo...
# 2  @POTUS Gas prices are down only because you ar...
# 3  https://t.co/HEMuIIrFin Oil “Quality News Link...
# 4  @SenatorLankford You do know that US is the la...
#
#                                           2022-12-01  \
# 0  @BBCNews You have a responsibility to explain ...
# 1                  @Marmee33 https://t.co/MeXmoIOgc9
# 2  @Sadiksmart7 @mohamedamiin2 @Qatari You can't ...
# 3  ¡Oil &amp; Gas Reporter está disponible! https...
# 4  #Gold #Silver and #Crypto update for 12/01/22 ...
#
#                                           2022-12-02  \
# 0  @GustavoBolivar Es una afrenta para la industr...
# 1  @JDCocchiarella Jack; I can answer that questi...
# 2  @diegowainstein El colectivo trucho de feminis...
# 3  Cut off from Russian gas and oil imports, much...
# 4  ¡Oil &amp; Gas Reporter está disponible! https...
#
#                                           2022-12-03  \
# 0  @SenateGOP Except the oil and gas companies do...
# 1  @GOP And Biden has created more jobs in 2 year...
# 2  @SandyHasCandy @TomTSEC And somehow, in your b...
# 3  @MichelleSteelCA If only our idiot Prime Minis...
# 4  PUMP AMERICAN OIL/NG NOW TO SAVE THE US ECONOM...
#
#                                           2022-12-04  \
# 0  @BladeoftheS He thinks nurses shouldn’t get a ...
# 1  @POTUS No thanks on your nuclear energy deal d...
# 2  @Julesmerch @ABC Has nothing to do with oil, n...
# 3  ¡Oil &amp; Gas Reporter está disponible! https...
# 4  Not to be that guy, but, this fossil fuel geop...
#
#                                           2022-12-05
# 0  Just When We Thought King Coal Was a Pauper\n#...
# 1  Alberta officials withholding list of 100s of ...
# 2  @GavinNewsom Californians are the only state p...
# 3  Two energy industry groups filed a lawsuit tod...
# 4  @GavinNewsom It's time for California to stop ...

# %%
twitter_df.tail()
# current twitter_df format: 3310, 13 (rows, columns)
# new twitter_df format: 43043, 1 (rows, columns)
# Out:
#       Unnamed: 0                                         2022-11-24  \
# 3306        3810  @johnredwood We can't frack, have new nuclear ...
# 3307        3813  @ThatgirlchrisC_ There are three mainparts in ...
# 3308        3814  @HeatherRaymon20 There are three mainparts in ...
# 3309        3815  Weakness in WCS price and Canadian oil stocks ...
# 3310        3817  @AnneCroucher @CaryKelly11 There are three mai...
#
#                                              2022-11-25  \
# 3306  @POTUS Moderating ??? Gas is going up again, o...
# 3307  @baseball31 Oh yeah you do and it is put you r...
# 3308  @PierrePoilievre Oil and gas or antithetical t...
# 3309  @AniB64 @KyivIndependent That's the milion $ q...
# 3310  Reducing emissions from Canada's #oilandgas in...
#
#                                              2022-11-26  \
# 3306  @OliviaG37717638 And the UK government priorit...
# 3307  @VincentH112 @Aidan_Regan @businessposthq Big ...
# 3308  Democrats are still in control of the Presiden...
# 3309  @BMoens It is not the US's fault that Europe w...
# 3310  @kaczyzm_2 @AMG26 @UserHomey @thesiriusreport ...
#
#                                              2022-11-27  \
# 3306  @RachelNotley High prices wouldn’t matter if y...
# 3307  @mabuhaytrucking @mirandadevine what purpose f...
# 3308  @StephenKing Electric cars use more oil than g...
# 3309  @UGM043 @RBROYB139 @II_Ogirima @IjeleWills @St...
# 3310  @groth1945 Not only that but where will the el...
#
#                                              2022-11-28  \
# 3306  Sabah should install meter gauge to record oil...
# 3307  The Latest Oil and Gas News! https://t.co/s6f8...
# 3308  Europe and the US are deep into the hunt for e...
# 3309  @castlvillageman Money!\nScotland's budget is ...
# 3310  https://t.co/4woRdsEWrr "The desire of the wes...
#
#                                              2022-11-29  \
# 3306  @GBNEWS @LiamHalligan sunak and hunt trying to...
# 3307  🥚🍤🍒🍊🍯🍞🥐🥖🥞🍯🍞🥐🥖🍎🍐🍊🥫🍳🥚🍋🍌🍉🥦🍎🍍🍑🍇🍓🍅🥕🌽🍳🥚🍲Oil and gas ...
# 3308  🥖🥞🍯🍞🥐🥖🍎🍐🍊🥫🍳🥚🍋🍌🍉🥦🍎🍍🍑🍇🍓🍅🥕🌽🍳🥚🍲🍐🍳🥚🍤Oil and gas bac...
# 3309  @GavinNewsom California has the highest per ga...
# 3310  blah blah blah\nhttps://t.co/DyJuuuoVti @Eveni...
#
#                                              2022-11-30  \
# 3306  @XDoc5O @geemangeegee @GOPLeader Would you pre...
# 3307  @DAMIADENUGA Say please I need money to start ...
# 3308  @MKarnitschnig Pesky Americans kept them from ...
# 3309  Five major oil refiners refuse to show up at s...
# 3310  Mexico's Pemex increases production and import...
#
#                                              2022-12-01  \
# 3306  @TamimBinHamad Dear Ursula Von Der Leyen, King...
# 3307  Crayfish, garri, cooking gas, vegetables and c...
# 3308  @xbasslichtie @YesEastAyrshire @RhodaMiller14 ...
# 3309  @TamimBinHamad @TebbouneAmadjid Dear Ursula Vo...
# 3310  Russian Upstream Oil And Gas Investment Set To...
#
#                                              2022-12-02  \
# 3306  Gordon sues Biden administration over oil and ...
# 3307  @CafInsider @TheProcessLives the EU has paid r...
# 3308  Why are Gulf oil and gas producers so keen to ...
# 3309  If only he'd said "this afternoon I met fossil...
# 3310  Mosman Oil &amp; Gas - Director Holdings #MSMN...
#
#                                              2022-12-03  \
# 3306  @billywade5014 @EngelbertRober2 @GregAbbott_TX...
# 3307  And how is @LancetCountdown and the many other...
# 3308  @RachelNotley OMG so true ❤ We should turn off...
# 3309  @blue_highland Nothing to do with religion we ...
# 3310  @BladeoftheS Tories only worship themselves, m...
#
#                                              2022-12-04  \
# 3306  Alex Christoforou Update: No reverse gear, EU ...
# 3307  Gas prices are down, oil production is up, and...
# 3308  @POTUS Now make an EV that charges as fast as ...
# 3309  @POTUS ...with electricity largely created by ...
# 3310  @Ronifae @sullim01 @AIWashburn @MichaelJStern1...
#
#                                              2022-12-05
# 3306  @POTUS The oil delivery guy just warned us tha...
# 3307  @Carolyn33127771 @Swifter38191895 @GoodKharma1...
# 3308  Oil and gas will still be the dominant source ...
# 3309  @AP CHINA RUSSIA BIGGEST COAL, GAS, OIL, FOSSI...
# 3310  Libya Oil, Gas and Renewable Energies Expo 202...

# %%
#twitter_df_1d = np.array(twitter_df.reshape(43043, 1))
#twitter_df_1d = twitter_df.values.reshape(43043, 1)
switchbag = twitter_df.values.reshape(43043, 1)
twitter_df = pd.DataFrame(switchbag)

# %%
twitter_df.head()
# Out:
#                                                    0
# 0                                                  0
# 1  @BellaWallerstei They have been paying oil and...
# 2  @TrainerGonzo @Belinda71555585 It's that easy ...
# 3  @HouseGOP They tried to stick the gas price hi...
# 4    @GilHough @KamalaHarris https://t.co/LBgWDBW9xs

# %%
# Adding column name to tweets

twitter_df = twitter_df.rename(columns = {'0':'Tweets'})
twitter_df.head()
# Out:
#                                                    0
# 0                                                  0
# 1  @BellaWallerstei They have been paying oil and...
# 2  @TrainerGonzo @Belinda71555585 It's that easy ...
# 3  @HouseGOP They tried to stick the gas price hi...
# 4    @GilHough @KamalaHarris https://t.co/LBgWDBW9xs

# %%
twitter_df = pd.DataFrame(columns=['polarity_score', 'subjectivity_score'])

# Adding columns 
polarity_scores = []
subjectivity_scores = []
tweets = []

for tweet in tweets:
    doc = nlp(tweet)
    for token in doc:
        print

with open('tweets_clean.csv', 'r') as f:
    for line in tqdm(f, total=10000):
        tweet_dict, tweets, tweets_doc = 
        tweet_dict = json.loads(line)
        tweets = tweet_dict['text']
        tweets_doc = nlp(tweets)
        # 4. polarity score for each tweet (emotions expressed)
        polarity_scores.append(tweets_doc._.blob.polarity)
        # 5. subjectivity score for each tweet (personal feelings, views, beliefs expressed in the tweet)
        subjectivity_scores.append(tweets_doc._.blob.subjectivity)
        tweets.append(tweets)

twitter_df['polarity_score'] = polarity_scores
twitter_df['subjectivity_score'] = subjectivity_scores
twitter_df['tweets'] = tweets
# Out:
#   0%|          | 0/10000 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# /Users/annettedblackburn/Desktop/Data_Analytics_Bootcamp/Module 20 - Final (Group) Project/twitter_NLP.ipynb Cell 10 in <cell line: 4>()
#       <a href='vscode-notebook-cell:/Users/annettedblackburn/Desktop/Data_Analytics_Bootcamp/Module%2020%20-%20Final%20%28Group%29%20Project/twitter_NLP.ipynb#ch0000008?line=3'>4</a> with open('tweets_clean.csv', 'r') as f:
#       <a href='vscode-notebook-cell:/Users/annettedblackburn/Desktop/Data_Analytics_Bootcamp/Module%2020%20-%20Final%20%28Group%29%20Project/twitter_NLP.ipynb#ch0000008?line=4'>5</a>     for line in tqdm(f, total=10000):
# ----> <a href='vscode-notebook-cell:/Users/annettedblackburn/Desktop/Data_Analytics_Bootcamp/Module%2020%20-%20Final%20%28Group%29%20Project/twitter_NLP.ipynb#ch0000008?line=5'>6</a>         tweet_dict = json.loads(line)
#       <a href='vscode-notebook-cell:/Users/annettedblackburn/Desktop/Data_Analytics_Bootcamp/Module%2020%20-%20Final%20%28Group%29%20Project/twitter_NLP.ipynb#ch0000008?line=6'>7</a>         tweets = tweet_dict['text']
#       <a href='vscode-notebook-cell:/Users/annettedblackburn/Desktop/Data_Analytics_Bootcamp/Module%2020%20-%20Final%20%28Group%29%20Project/twitter_NLP.ipynb#ch0000008?line=7'>8</a>         tweets_doc = nlp(tweets)
#
# File /opt/anaconda3/envs/CompSoc/lib/python3.8/json/__init__.py:357, in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     352     del kw['encoding']
#     354 if (cls is None and object_hook is None and
#     355         parse_int is None and parse_float is None and
#     356         parse_constant is None and object_pairs_hook is None and not kw):
# --> 357     return _default_decoder.decode(s)
#     358 if cls is None:
#     359     cls = JSONDecoder
#
# File /opt/anaconda3/envs/CompSoc/lib/python3.8/json/decoder.py:337, in JSONDecoder.decode(self, s, _w)
#     332 def decode(self, s, _w=WHITESPACE.match):
#     333     """Return the Python representation of ``s`` (a ``str`` instance
#     334     containing a JSON document).
#     335
#     336     """
# --> 337     obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     338     end = _w(s, end).end()
#     339     if end != len(s):
#
# File /opt/anaconda3/envs/CompSoc/lib/python3.8/json/decoder.py:355, in JSONDecoder.raw_decode(self, s, idx)
#     353     obj, end = self.scan_once(s, idx)
#     354 except StopIteration as err:
# --> 355     raise JSONDecodeError("Expecting value", s, err.value) from None
#     356 return obj, end
#
# JSONDecodeError: Expecting value: line 1 column 1 (char 0)

# %%
twitter_df.head()

# %%
# Drop NAs
twitter_df.dropna()

# %% [markdown]
# ## Using spacy's English language model, individual tweets are tokenized and the following are collected:
# 1. total number of words
# 2. total number of punctuation marks
# 3. total number of words that are not stop words
# 4. polarity score (emotions expressed in the tweet)
# 5. subjectivity score (personal feelings, views, or beliefs expressed in the tweet)

# %%
# 1. total number of words
def count_words(text):
    words = text.split()
    return len(words)

twitter_df['word_count'] = twitter_df["review"].apply(count_words)
twitter_df.head()

# %%
# 2. total number of punctuation marks for each tweet
def count_punct_marks(text):
    char_count = 0
    for cha in text:
        if cha in PUNCTUATION:
            char_count+=1
    return char_count

twitter_df['punct_count'] = twitter_df["review"].apply(count_punct_marks)
twitter_df.head()

# %%
# 3. total number of words that are not stop words for each tweet
def count_non_stop_words(text):
    non_stop_words = pd.Series(text.split())
    non_stop_words.str.strip(PUNCTUATION)

    drop_list = []
    for idx, word in enumerate(non_stop_words):
        if word in STOP_WORDS:
            drop_list.append(idx)
    non_stop_words.drop(index=drop_list, inplace=True)
    return len(non_stop_words)


twitter_df['non_stop_words'] = twitter_df["review"].apply(count_non_stop_words)
twitter_df.head()

# %% [markdown]
# ## Description of Preliminary Data Preprocessing

# %% [markdown]
# ## Data Examining & Cleaning

# %% [markdown]
# # Sentiment Analysis Natural Language Processing Machine Learning Model
#
# ## Description of Preliminary Feature Engineering and Preliminary Feature Selection
#
#
# # Explanation of Model Choice, including Limitations and Benefits

# %%
# X = 
# Y =
